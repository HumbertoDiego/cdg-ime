# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/HumbertoDiego/cdg-ime/blob/main/02_Prospecção.ipynb)

# %% [markdown]
# # Ciência de Dados Geoespaciais - Prospecção
#
# **Maj Diego - 2° Semestre / 2026**
#
# **Objetivos**
#
# 1. Conceituar ciência de dados;
# 2. Especificar dados para análise;
# 3. Identificar datasets públicos;
# 4. Conceituar API e como ser cliente de uma API;
# 5. Conceituar a especificação de Geosserviços OGC;
# 6. Conceituar a especificação de catalogação STAC;
# 7. Web scraping: obter dados sem API;
# 8. Realizar a prospecção de trabalhos acadêmicos.

# %% [markdown]
# ## 1. Conceituar ciência de dados
#
# **Ciência de Dados** é um campo interdisciplinar que combina estatística, computação e conhecimento de domínio para extrair conhecimento e insights a partir de dados estruturados e não estruturados.
#
# ### **1.1 O que é Ciência de Dados Geoespaciais?**
#
# A **Ciência de Dados Geoespaciais** aplica os métodos de ciência de dados a dados que possuem **componente espacial** — ou seja, dados que podem ser referenciados a um local na superfície terrestre.
#
# Exemplos de perguntas que ela responde:
# - Onde há maior risco de deslizamento de encosta?
# - Como a temperatura urbana varia em função da cobertura vegetal?
# - Quais regiões apresentam maior vulnerabilidade logística?

# %% [markdown]
# ### **1.2 O pipeline de ciência de dados**
#
# | Etapa | Descrição | Ferramentas comuns |
# |-------|-----------|--------------------|
# | **Prospecção** | Identificar e coletar dados | APIs, web scraping, portais abertos |
# | **Tratamento/Pré-processamento** | Limpar, transformar e integrar | pandas, geopandas, GDAL |
# | **Exploração/Mineração** | Analisar estatísticas e visualizar | matplotlib, seaborn, folium |
# | **Modelagem** | Aplicar algoritmos e modelos | scikit-learn, statsmodels |
# | **Análise do resultado** | Apresentar resultados | dashboards, mapas, relatórios |

# %% [markdown]
# ### **1.3 A importância da pergunta**
#
# Antes de coletar qualquer dado, é essencial formular uma **pergunta clara e mensurável**. Perguntas vagas levam a coletas desnecessárias e análises sem foco.
#
# | Pergunta vaga | Pergunta bem formulada |
# |--------------|------------------------|
# | "Onde há crime?" | "Qual a densidade de ocorrências de roubo por km² nos bairros do Rio de Janeiro em 2023?" |
# | "Como está o trânsito?" | "Qual o tempo médio de deslocamento entre Niterói e o Centro do Rio às 8h nos dias úteis?" |

# %% [markdown]
# ## 2. Especificar dados para análise
#
# ### **2.1 Tipos de dados quanto à estrutura**
#
# | Tipo | Descrição | Exemplo |
# |------|-----------|----------|
# | **Estruturado** | Organizado em tabelas com schema fixo | Censo IBGE em .csv |
# | **Semi-estruturado** | Tem organização, mas sem schema rígido | JSON de API, XML |
# | **Não estruturado** | Sem organização predefinida | Texto livre, imagens de satélite |

# %% [markdown]
# ### **2.2 Tipos de dados geoespaciais**

# %% [markdown]
# <img src="media/imgs/raster_vetor.png">

# %% [markdown]
# #### **2.2.1 Modelo vetorial**
#
# Dados vetoriais são tipologias de dados espaciais que representam o espaço geográfico por meio de pontos, linhas ou polígonos. Ao contrário dos dados raster, eles não representam o espaço geográfico de forma contínua, mas sim, delimitada.
#
# **Exercício**
# Quais destas primitivas vetoriais você escolheria para representar estes elementos espaciais: *localidades, estações, ocorrências, rios, rodovias, redes de transporte, área do municípios, bacias hidrográficas e lotes*.
#
# - **Ponto**: ?
# - **Linha**: ?
# - **Polígono**: ?
#
# Existem ainda situações que um geo-objeto pode assumir mais de uma primitiva, a ET-EDGV as nomeia como classes `complexas`.

# %% [markdown]
# **As primitivas vetoriais são plotadas, como coordenadas em um gráfico:**

# %%
import geopandas as gpd
from shapely import wkt
import matplotlib.pyplot as plt

# ── Geometrias em WKT ────────────────────────────────────────
ponto   = wkt.loads("POINT (0 0)")
linha   = wkt.loads("LINESTRING (2 -1, 2.5 0, 3 1, 3.5 0, 4 -1)")
poligono = wkt.loads("POLYGON ((6 -1, 8 -1, 8 1, 6 1, 6 -1))")

# ── GeoDataFrame com os três tipos ───────────────────────────
gdf = gpd.GeoDataFrame(
    {
        "tipo"  : ["Ponto", "Linha", "Polígono"],
        "wkt"   : [ponto.wkt, linha.wkt, poligono.wkt],
        "geometry": [ponto, linha, poligono],
    },
    crs="EPSG:4326",
)

# ── Plot ──────────────────────────────────────────────────────
cores = ["#e74c3c", "#2980b9", "#27ae60"]

fig, ax = plt.subplots(figsize=(9, 4))

# Polígono (fundo + borda)
gdf[gdf.geom_type == "Polygon"].plot(
    ax=ax, color="#27ae60", edgecolor="#1a6e3c", linewidth=2, alpha=0.6, label="Polígono"
)
# Linha
gdf[gdf.geom_type == "LineString"].plot(
    ax=ax, color="#2980b9", linewidth=2.5, label="Linha"
)
# Ponto
gdf[gdf.geom_type == "Point"].plot(
    ax=ax, color="#e74c3c", markersize=120, zorder=5, label="Ponto"
)

# Rótulos de tipo sobre cada geometria
for _, row in gdf.iterrows():
    cx, cy = row.geometry.centroid.x, row.geometry.centroid.y
    ax.annotate(row["tipo"], xy=(cx, cy), xytext=(0, 14),
                textcoords="offset points", ha="center",
                fontsize=11, fontweight="bold")

ax.set_title("Geometrias WKT com GeoPandas", fontsize=13)
plt.show()

# ── Inspecionar WKTs ─────────────────────────────────────────
print(gdf[["tipo", "wkt"]].to_string(index=False))
# Out:
#     tipo                                        wkt
#    Ponto                                POINT (0 0)
#    Linha LINESTRING (2 -1, 2.5 0, 3 1, 3.5 0, 4 -1)
# Polígono     POLYGON ((6 -1, 8 -1, 8 1, 6 1, 6 -1))

# %% [markdown]
# #### **2.2.2 Ferramentas para construção de uma geoinformação vetorial**
#
# [**Well Known Text (WKT)**](https://wktmap.com/): As geometrias textuais WKT são usadas em todas as especificações OGC e estão presentes em aplicações que implementam essas especificações (GDAL OGR, PostGIS, geopandas, ... ) tornando possível converter geometrias *para* e *de* uma representação WKT.
#
# As coordenadas para geometrias podem ser 2D (x, y), 3D (x, y, z), 4D (x, y, z, m) com um valor m que faz parte de um sistema de referenciamento linear ou 2D com um valor m (x, y, m), por exemplo:
#
# As três primitivas básicas:
# - Ponto `POINT (0 0)`
# - Linha `LINESTRING (2 -1, 2.5 0, 3 1, 3.5 0, 4 -1)`
# - Polígono `POLYGON ((6 -1, 8 -1, 8 1, 6 1, 6 -1))` $\leftarrow$ ponto final = ponto inicial

# %% [markdown]
# As derivações básicas:
# - Ponto-3D `POINT Z (0 0 0)`
# - Linha-3D `LINESTRING Z (2 -1 0, 2.5 0 0, 3 1 0, 3.5 0 0, 4 -1 0)`
# - Polígono-3D `POLYGON Z (6 -1 0, 8 -1 0, 8 1 0, 6 1 0, 6 -1 0)`
# - Multi-Ponto `MULTIPOINT  ((0 0),(1 1))`
# - Multi-Linha `MULTILINESTRING  ((2 -1, 2 0, 3 1, 3 0, 4 -1), (0 0, 1 1, 3 -1, 3 0, 4 1))`
# - Multi-Polígono `MULTIPOLYGON ((6 -1, 8 -1, 8 1, 6 1, 6 -1), (6 -1, 8 -1, 8 1, 6 1, 6 -1))`
# - Coleção-Geométrica: `GEOMETRYCOLLECTION (POINT (40 10),LINESTRING (10 10, 20 20, 10 40), POLYGON ((40 40, 20 45, 45 30, 40 40)))`
#
# E muitas outras:
# - CircularString, CompoundCurve, CurvePolygon, MultiCurve, MultiSurface, Curve, Surface, PolyhedralSurface, TIN, Triangle, Circle, GeodesicString, EllipticalCurve, NurbsCurve, Clothoid, SpiralCurve, CompoundSurface, BrepSolid, AffinePlacement.

# %% [markdown]
# #### **2.2.2 Ferramentas para construção de uma geoinformação vetorial**
#
# [**GeoJSON**](https://geojson.io/#map=3.8/-12.97/-53.94): Um formato textual para codificar uma variedade de estruturas de dados geográficos baseado em JavaScript Object Notation (JSON). Usado para representar características geográficas simples, juntamente com seus atributos não espaciais. Também é amplamente usado em mapas web (Leaflet, Mapbox, Google Maps), APIs de geolocalização e ferramentas como QGIS.
#
# O GeoJSON suporta vários tipos de geometria, como Ponto, Linha, Polígono, Multiponto, Multilinha, Multipolígono e Coleção de Geometrias. Cada geo-objeto (GeoJSON *feature*) pode ter propriedades adicionais informando uma determinada característica.

# %% [markdown]
# Exemplo de GeoJSON:
#
# ```json
# {
#   "type": "FeatureCollection",
#   "features": [
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [-43.1729, -22.9068]
#       },
#       "properties": {"nome": "Cristo Redentor", "categoria": "monumento" }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "LineString",
#         "coordinates": [[-43.18, -22.9], [-43.18, -22.9], [-43.18, -22.9]]
#       },
#       "properties": {"nome": "Caminho até o Cristo", "tipo": "trilha" }
#     }
#   ]
# }
# ```

# %% [markdown]
# #### **2.2.3 Modelo raster**
#
# Representa dados como uma grade regular de células (pixels), cada uma com um valor:
# - Imagens de satélite (Landsat, Sentinel)
# - Modelos Digitais de Elevação (MDE)
# - Grades climáticas (temperatura, precipitação)
#
# Esse modelo também é chamado de modelo matricial. Uma fotografia como a conhecemos é apenas 3 matrizes empilhadas, representando o nível de cores vermelho, verde e azul (RGB). Por exemplo, uma imagem de 3x3x3:
#
# $
# I = \begin{bmatrix}
# [255, 0, 0] & [0, 255, 0] & [0, 0, 255] \\
# [255, 255, 0] & [0, 255, 255] & [255, 0, 255] \\
# [192, 192, 192] & [128, 128, 128] & [64, 64, 64]
# \end{bmatrix}
# $
#
# É renderizada da seguinte forma:
#
# <div><div style="display:flex;gap:0px"><div style="width:50px;height:50px;background-color:rgb(255, 0, 0)"></div><div style="width:50px;height:50px;background-color:rgb(0, 255, 0)"></div><div style="width:50px;height:50px;background-color:rgb(0, 0, 255)"></div></div><div style="display:flex;gap:0px"><div style="width:50px;height:50px;background-color:rgb(255, 255, 0)"></div><div style="width:50px;height:50px;background-color:rgb(0, 255, 255)"></div><div style="width:50px;height:50px;background-color:rgb(255, 0, 255)"></div></div><div style="display:flex;gap:0px"><div style="width:50px;height:50px;background-color:rgb(192, 192, 192)"></div><div style="width:50px;height:50px;background-color:rgb(128, 128, 128)"></div><div style="width:50px;height:50px;background-color:rgb(64, 64, 64)"></div></div></div>

# %% [markdown]
# **Resolução espacial do dado raster**: tamanho do pixel no terreno (GSD — Ground Sampling Distance). Ex.: 10 m → cada pixel representa no terreno um quadrado 10×10 m.
#
# <img src="media/imgs/res-espacial-QGIS.png">

# %% [markdown]
# **Resolução radiométrica do dado raster**: Número de níveis de intensidade que cada pixel pode representar (quantização), normalmente em bits por banda. O valor do pixel pode variar da seguinte forma:
#
# |Nome|Qt de bits | Valor min | Valor máx|
# |-|- | - | -|
# |`byte` ou `uint8`|8 bit|0|255|
# |`uint16`|16 bit|0|65535|
# |`uint32`|32 bit|0|4294967295|
# |`uint64`|64 bit|0|2^64 - 1|
# |`int8`|8 bit|-128|127|
# |`int16`|16 bit|-32768|32767|
# |`int32`|32 bit|-2147483648|2147483647|
# |`int64`|64 bit|-2^63|2^63 - 1|
# |`float16`|16 bit|−65504.0|65504.0|
# |`float32`|32 bit|-3.4028235e+38|3.4028235e+38|
# |`float64`|64 bit|-1.7976931348623157e+308|1.7976931348623157e+308|

# %% [markdown]
# **Resolução espectral do dado raster**: número e largura das bandas (p. ex. RGB, multispectral, hiperespectral). Por exemplo, as imagens da missão [**Sentinel 2**](https://sentiwiki.copernicus.eu/web/s2-mission#S2-Mission-Spatial-Resolution) possuem as seguintes bandas:
#
# Bandas com resolução espacial 10m:
#
# <img src="media/imgs/s2-10m.png">
#
# Bandas com resolução espacial 20m:
#
# <img src="media/imgs/s2-20m.png">

# %% [markdown]
# **Resolução espectral do dado raster**: número e largura das bandas (p. ex. RGB, multispectral, hiperespectral). Por exemplo, as imagens da missão **[Sentinel 2](https://sentiwiki.copernicus.eu/web/s2-mission#S2-Mission-Spatial-Resolution)** possuem as seguintes bandas:
#
# Bandas com resolução espacial 60m:
#
# <img src="media/imgs/s2-60m.png">

# %% [markdown]
# **Olhando mais a fundo um dado raster (`gdalinfo`)**

# %%
import os
import gdown
if not os.path.exists("./JB_hiper.tif"):
    gdown.download( id= "1G7tuNW-r0uxZ25OR66MZ9su4fMk8cGKW", output="./JB_hiper.tif", quiet=True)
qgis_gdal_path = 'C:/Program Files/QGIS 3.44.11/bin' # 'ajustar
!"{qgis_gdal_path}/gdalinfo.exe" JB_hiper.tif
# Out:
# Driver: GTiff/GeoTIFF
# Files: JB_hiper.tif
# Size is 613, 434
# Coordinate System is:
# PROJCRS["WGS 84 / UTM zone 23S",
#     BASEGEOGCRS["WGS 84",
#         DATUM["World Geodetic System 1984",
#             ELLIPSOID["WGS 84",6378137,298.257223563,
#                 LENGTHUNIT["metre",1]]],
#         PRIMEM["Greenwich",0,
#             ANGLEUNIT["degree",0.0174532925199433]],
#         ID["EPSG",4326]],
#     CONVERSION["UTM zone 23S",
#         METHOD["Transverse Mercator",
#             ID["EPSG",9807]],
#         PARAMETER["Latitude of natural origin",0,
#             ANGLEUNIT["degree",0.0174532925199433],
#             ID["EPSG",8801]],
#         PARAMETER["Longitude of natural origin",-45,
#             ANGLEUNIT["degree",0.0174532925199433],
#             ID["EPSG",8802]],
#         PARAMETER["Scale factor at natural origin",0.9996,
#             SCALEUNIT["unity",1],
#             ID["EPSG",8805]],
#         PARAMETER["False easting",500000,
#             LENGTHUNIT["metre",1],
#             ID["EPSG",8806]],
#         PARAMETER["False northing",10000000,
#             LENGTHUNIT["metre",1],
#             ID["EPSG",8807]]],
#     CS[Cartesian,2],
#         AXIS["(E)",east,
#             ORDER[1],
#             LENGTHUNIT["metre",1]],
#         AXIS["(N)",north,
#             ORDER[2],
#             LENGTHUNIT["metre",1]],
#     USAGE[
#         SCOPE["Navigation and medium accuracy spatial referencing."],
#         AREA["Between 48°W and 42°W, southern hemisphere between 80°S and equator, onshore and offshore. Brazil."],
#         BBOX[-80,-48,0,-42]],
#     ID["EPSG",32723]]
# Data axis to CRS axis mapping: 1,2
# Origin = (682026.399999982211739,7458976.000003093853593)
# Pixel Size = (0.399999999999990,-0.400000000000166)
# Metadata:
#   AREA_OR_POINT=Area
# Image Structure Metadata:
#   INTERLEAVE=PIXEL
# Corner Coordinates:
# Upper Left  (  682026.400, 7458976.000) ( 43d13'27.97"W, 22d58' 3.04"S)
# Lower Left  (  682026.400, 7458802.400) ( 43d13'27.90"W, 22d58' 8.68"S)
# Upper Right (  682271.600, 7458976.000) ( 43d13'19.36"W, 22d58' 2.94"S)
# Lower Right (  682271.600, 7458802.400) ( 43d13'19.29"W, 22d58' 8.58"S)
# Center      (  682149.000, 7458889.200) ( 43d13'23.63"W, 22d58' 5.81"S)
# Band 1 Block=613x1 Type=Float32, ColorInterp=Gray
#   Description = Layer (Mosaic (Band 1):mosaic_1_2_3) (397.947998 Nanometers)
#   NoData Value=nan
# Band 2 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 2):mosaic_1_2_3) (400.161987 Nanometers)
#   NoData Value=nan
# Band 3 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 3):mosaic_1_2_3) (402.375000 Nanometers)
#   NoData Value=nan
# Band 4 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 4):mosaic_1_2_3) (404.588989 Nanometers)
#   NoData Value=nan
# Band 5 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 5):mosaic_1_2_3) (406.803009 Nanometers)
#   NoData Value=nan
# Band 6 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 6):mosaic_1_2_3) (409.015991 Nanometers)
#   NoData Value=nan
# Band 7 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 7):mosaic_1_2_3) (411.230011 Nanometers)
#   NoData Value=nan
# Band 8 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 8):mosaic_1_2_3) (413.442993 Nanometers)
#   NoData Value=nan
# Band 9 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 9):mosaic_1_2_3) (415.657013 Nanometers)
#   NoData Value=nan
# Band 10 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 10):mosaic_1_2_3) (417.871002 Nanometers)
#   NoData Value=nan
# Band 11 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 11):mosaic_1_2_3) (420.084015 Nanometers)
#   NoData Value=nan
# Band 12 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 12):mosaic_1_2_3) (422.298004 Nanometers)
#   NoData Value=nan
# Band 13 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 13):mosaic_1_2_3) (424.510986 Nanometers)
#   NoData Value=nan
# Band 14 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 14):mosaic_1_2_3) (426.725006 Nanometers)
#   NoData Value=nan
# Band 15 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 15):mosaic_1_2_3) (428.937988 Nanometers)
#   NoData Value=nan
# Band 16 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 16):mosaic_1_2_3) (431.152008 Nanometers)
#   NoData Value=nan
# Band 17 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 17):mosaic_1_2_3) (433.365997 Nanometers)
#   NoData Value=nan
# Band 18 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 18):mosaic_1_2_3) (435.579010 Nanometers)
#   NoData Value=nan
# Band 19 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 19):mosaic_1_2_3) (437.792999 Nanometers)
#   NoData Value=nan
# Band 20 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 20):mosaic_1_2_3) (440.006012 Nanometers)
#   NoData Value=nan
# Band 21 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 21):mosaic_1_2_3) (442.220001 Nanometers)
#   NoData Value=nan
# Band 22 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 22):mosaic_1_2_3) (444.433014 Nanometers)
#   NoData Value=nan
# Band 23 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 23):mosaic_1_2_3) (446.647003 Nanometers)
#   NoData Value=nan
# Band 24 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 24):mosaic_1_2_3) (448.860992 Nanometers)
#   NoData Value=nan
# Band 25 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 25):mosaic_1_2_3) (451.074005 Nanometers)
#   NoData Value=nan
# Band 26 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 26):mosaic_1_2_3) (453.287994 Nanometers)
#   NoData Value=nan
# Band 27 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 27):mosaic_1_2_3) (455.501007 Nanometers)
#   NoData Value=nan
# Band 28 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 28):mosaic_1_2_3) (457.714996 Nanometers)
#   NoData Value=nan
# Band 29 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 29):mosaic_1_2_3) (459.928009 Nanometers)
#   NoData Value=nan
# Band 30 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 30):mosaic_1_2_3) (462.141998 Nanometers)
#   NoData Value=nan
# Band 31 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 31):mosaic_1_2_3) (464.355988 Nanometers)
#   NoData Value=nan
# Band 32 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 32):mosaic_1_2_3) (466.569000 Nanometers)
#   NoData Value=nan
# Band 33 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 33):mosaic_1_2_3) (468.782990 Nanometers)
#   NoData Value=nan
# Band 34 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 34):mosaic_1_2_3) (470.996002 Nanometers)
#   NoData Value=nan
# Band 35 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 35):mosaic_1_2_3) (473.209991 Nanometers)
#   NoData Value=nan
# Band 36 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 36):mosaic_1_2_3) (475.424011 Nanometers)
#   NoData Value=nan
# Band 37 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 37):mosaic_1_2_3) (477.636993 Nanometers)
#   NoData Value=nan
# Band 38 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 38):mosaic_1_2_3) (479.851013 Nanometers)
#   NoData Value=nan
# Band 39 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 39):mosaic_1_2_3) (482.063995 Nanometers)
#   NoData Value=nan
# Band 40 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 40):mosaic_1_2_3) (484.278015 Nanometers)
#   NoData Value=nan
# Band 41 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 41):mosaic_1_2_3) (486.490997 Nanometers)
#   NoData Value=nan
# Band 42 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 42):mosaic_1_2_3) (488.704987 Nanometers)
#   NoData Value=nan
# Band 43 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 43):mosaic_1_2_3) (490.919006 Nanometers)
#   NoData Value=nan
# Band 44 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 44):mosaic_1_2_3) (493.131989 Nanometers)
#   NoData Value=nan
# Band 45 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 45):mosaic_1_2_3) (495.346008 Nanometers)
#   NoData Value=nan
# Band 46 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 46):mosaic_1_2_3) (497.558990 Nanometers)
#   NoData Value=nan
# Band 47 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 47):mosaic_1_2_3) (499.773010 Nanometers)
#   NoData Value=nan
# Band 48 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 48):mosaic_1_2_3) (501.985992 Nanometers)
#   NoData Value=nan
# Band 49 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 49):mosaic_1_2_3) (504.200012 Nanometers)
#   NoData Value=nan
# Band 50 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 50):mosaic_1_2_3) (506.414001 Nanometers)
#   NoData Value=nan
# Band 51 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 51):mosaic_1_2_3) (508.627014 Nanometers)
#   NoData Value=nan
# Band 52 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 52):mosaic_1_2_3) (510.841003 Nanometers)
#   NoData Value=nan
# Band 53 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 53):mosaic_1_2_3) (513.054016 Nanometers)
#   NoData Value=nan
# Band 54 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 54):mosaic_1_2_3) (515.268005 Nanometers)
#   NoData Value=nan
# Band 55 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 55):mosaic_1_2_3) (517.481018 Nanometers)
#   NoData Value=nan
# Band 56 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 56):mosaic_1_2_3) (519.695007 Nanometers)
#   NoData Value=nan
# Band 57 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 57):mosaic_1_2_3) (521.908997 Nanometers)
#   NoData Value=nan
# Band 58 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 58):mosaic_1_2_3) (524.122009 Nanometers)
#   NoData Value=nan
# Band 59 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 59):mosaic_1_2_3) (526.335999 Nanometers)
#   NoData Value=nan
# Band 60 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 60):mosaic_1_2_3) (528.549011 Nanometers)
#   NoData Value=nan
# Band 61 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 61):mosaic_1_2_3) (530.763000 Nanometers)
#   NoData Value=nan
# Band 62 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 62):mosaic_1_2_3) (532.976990 Nanometers)
#   NoData Value=nan
# Band 63 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 63):mosaic_1_2_3) (535.190002 Nanometers)
#   NoData Value=nan
# Band 64 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 64):mosaic_1_2_3) (537.403992 Nanometers)
#   NoData Value=nan
# Band 65 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 65):mosaic_1_2_3) (539.617004 Nanometers)
#   NoData Value=nan
# Band 66 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 66):mosaic_1_2_3) (541.830994 Nanometers)
#   NoData Value=nan
# Band 67 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 67):mosaic_1_2_3) (544.044006 Nanometers)
#   NoData Value=nan
# Band 68 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 68):mosaic_1_2_3) (546.257996 Nanometers)
#   NoData Value=nan
# Band 69 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 69):mosaic_1_2_3) (548.471985 Nanometers)
#   NoData Value=nan
# Band 70 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 70):mosaic_1_2_3) (550.684998 Nanometers)
#   NoData Value=nan
# Band 71 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 71):mosaic_1_2_3) (552.898987 Nanometers)
#   NoData Value=nan
# Band 72 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 72):mosaic_1_2_3) (555.112000 Nanometers)
#   NoData Value=nan
# Band 73 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 73):mosaic_1_2_3) (557.325989 Nanometers)
#   NoData Value=nan
# Band 74 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 74):mosaic_1_2_3) (559.539001 Nanometers)
#   NoData Value=nan
# Band 75 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 75):mosaic_1_2_3) (561.752991 Nanometers)
#   NoData Value=nan
# Band 76 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 76):mosaic_1_2_3) (563.966980 Nanometers)
#   NoData Value=nan
# Band 77 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 77):mosaic_1_2_3) (566.179993 Nanometers)
#   NoData Value=nan
# Band 78 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 78):mosaic_1_2_3) (568.393982 Nanometers)
#   NoData Value=nan
# Band 79 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 79):mosaic_1_2_3) (570.606995 Nanometers)
#   NoData Value=nan
# Band 80 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 80):mosaic_1_2_3) (572.820984 Nanometers)
#   NoData Value=nan
# Band 81 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 81):mosaic_1_2_3) (575.033997 Nanometers)
#   NoData Value=nan
# Band 82 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 82):mosaic_1_2_3) (577.247986 Nanometers)
#   NoData Value=nan
# Band 83 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 83):mosaic_1_2_3) (579.461975 Nanometers)
#   NoData Value=nan
# Band 84 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 84):mosaic_1_2_3) (581.674988 Nanometers)
#   NoData Value=nan
# Band 85 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 85):mosaic_1_2_3) (583.888977 Nanometers)
#   NoData Value=nan
# Band 86 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 86):mosaic_1_2_3) (586.101990 Nanometers)
#   NoData Value=nan
# Band 87 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 87):mosaic_1_2_3) (588.315979 Nanometers)
#   NoData Value=nan
# Band 88 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 88):mosaic_1_2_3) (590.528992 Nanometers)
#   NoData Value=nan
# Band 89 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 89):mosaic_1_2_3) (592.742981 Nanometers)
#   NoData Value=nan
# Band 90 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 90):mosaic_1_2_3) (594.956970 Nanometers)
#   NoData Value=nan
# Band 91 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 91):mosaic_1_2_3) (597.169983 Nanometers)
#   NoData Value=nan
# Band 92 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 92):mosaic_1_2_3) (599.383972 Nanometers)
#   NoData Value=nan
# Band 93 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 93):mosaic_1_2_3) (601.596985 Nanometers)
#   NoData Value=nan
# Band 94 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 94):mosaic_1_2_3) (603.810974 Nanometers)
#   NoData Value=nan
# Band 95 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 95):mosaic_1_2_3) (606.025024 Nanometers)
#   NoData Value=nan
# Band 96 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 96):mosaic_1_2_3) (608.237976 Nanometers)
#   NoData Value=nan
# Band 97 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 97):mosaic_1_2_3) (610.452026 Nanometers)
#   NoData Value=nan
# Band 98 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 98):mosaic_1_2_3) (612.664978 Nanometers)
#   NoData Value=nan
# Band 99 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 99):mosaic_1_2_3) (614.879028 Nanometers)
#   NoData Value=nan
# Band 100 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 100):mosaic_1_2_3) (617.091980 Nanometers)
#   NoData Value=nan
# Band 101 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 101):mosaic_1_2_3) (619.306030 Nanometers)
#   NoData Value=nan
# Band 102 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 102):mosaic_1_2_3) (621.520020 Nanometers)
#   NoData Value=nan
# Band 103 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 103):mosaic_1_2_3) (623.732971 Nanometers)
#   NoData Value=nan
# Band 104 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 104):mosaic_1_2_3) (625.947021 Nanometers)
#   NoData Value=nan
# Band 105 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 105):mosaic_1_2_3) (628.159973 Nanometers)
#   NoData Value=nan
# Band 106 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 106):mosaic_1_2_3) (630.374023 Nanometers)
#   NoData Value=nan
# Band 107 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 107):mosaic_1_2_3) (632.586975 Nanometers)
#   NoData Value=nan
# Band 108 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 108):mosaic_1_2_3) (634.801025 Nanometers)
#   NoData Value=nan
# Band 109 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 109):mosaic_1_2_3) (637.015015 Nanometers)
#   NoData Value=nan
# Band 110 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 110):mosaic_1_2_3) (639.228027 Nanometers)
#   NoData Value=nan
# Band 111 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 111):mosaic_1_2_3) (641.442017 Nanometers)
#   NoData Value=nan
# Band 112 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 112):mosaic_1_2_3) (643.655029 Nanometers)
#   NoData Value=nan
# Band 113 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 113):mosaic_1_2_3) (645.869019 Nanometers)
#   NoData Value=nan
# Band 114 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 114):mosaic_1_2_3) (648.081970 Nanometers)
#   NoData Value=nan
# Band 115 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 115):mosaic_1_2_3) (650.296021 Nanometers)
#   NoData Value=nan
# Band 116 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 116):mosaic_1_2_3) (652.510010 Nanometers)
#   NoData Value=nan
# Band 117 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 117):mosaic_1_2_3) (654.723022 Nanometers)
#   NoData Value=nan
# Band 118 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 118):mosaic_1_2_3) (656.937012 Nanometers)
#   NoData Value=nan
# Band 119 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 119):mosaic_1_2_3) (659.150024 Nanometers)
#   NoData Value=nan
# Band 120 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 120):mosaic_1_2_3) (661.364014 Nanometers)
#   NoData Value=nan
# Band 121 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 121):mosaic_1_2_3) (663.578003 Nanometers)
#   NoData Value=nan
# Band 122 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 122):mosaic_1_2_3) (665.791016 Nanometers)
#   NoData Value=nan
# Band 123 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 123):mosaic_1_2_3) (668.005005 Nanometers)
#   NoData Value=nan
# Band 124 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 124):mosaic_1_2_3) (670.218018 Nanometers)
#   NoData Value=nan
# Band 125 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 125):mosaic_1_2_3) (672.432007 Nanometers)
#   NoData Value=nan
# Band 126 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 126):mosaic_1_2_3) (674.645020 Nanometers)
#   NoData Value=nan
# Band 127 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 127):mosaic_1_2_3) (676.859009 Nanometers)
#   NoData Value=nan
# Band 128 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 128):mosaic_1_2_3) (679.072998 Nanometers)
#   NoData Value=nan
# Band 129 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 129):mosaic_1_2_3) (681.286011 Nanometers)
#   NoData Value=nan
# Band 130 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 130):mosaic_1_2_3) (683.500000 Nanometers)
#   NoData Value=nan
# Band 131 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 131):mosaic_1_2_3) (685.713013 Nanometers)
#   NoData Value=nan
# Band 132 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 132):mosaic_1_2_3) (687.927002 Nanometers)
#   NoData Value=nan
# Band 133 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 133):mosaic_1_2_3) (690.140015 Nanometers)
#   NoData Value=nan
# Band 134 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 134):mosaic_1_2_3) (692.354004 Nanometers)
#   NoData Value=nan
# Band 135 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 135):mosaic_1_2_3) (694.567993 Nanometers)
#   NoData Value=nan
# Band 136 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 136):mosaic_1_2_3) (696.781006 Nanometers)
#   NoData Value=nan
# Band 137 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 137):mosaic_1_2_3) (698.994995 Nanometers)
#   NoData Value=nan
# Band 138 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 138):mosaic_1_2_3) (701.208008 Nanometers)
#   NoData Value=nan
# Band 139 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 139):mosaic_1_2_3) (703.421997 Nanometers)
#   NoData Value=nan
# Band 140 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 140):mosaic_1_2_3) (705.635010 Nanometers)
#   NoData Value=nan
# Band 141 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 141):mosaic_1_2_3) (707.848999 Nanometers)
#   NoData Value=nan
# Band 142 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 142):mosaic_1_2_3) (710.062988 Nanometers)
#   NoData Value=nan
# Band 143 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 143):mosaic_1_2_3) (712.276001 Nanometers)
#   NoData Value=nan
# Band 144 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 144):mosaic_1_2_3) (714.489990 Nanometers)
#   NoData Value=nan
# Band 145 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 145):mosaic_1_2_3) (716.703003 Nanometers)
#   NoData Value=nan
# Band 146 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 146):mosaic_1_2_3) (718.916992 Nanometers)
#   NoData Value=nan
# Band 147 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 147):mosaic_1_2_3) (721.130981 Nanometers)
#   NoData Value=nan
# Band 148 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 148):mosaic_1_2_3) (723.343994 Nanometers)
#   NoData Value=nan
# Band 149 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 149):mosaic_1_2_3) (725.557983 Nanometers)
#   NoData Value=nan
# Band 150 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 150):mosaic_1_2_3) (727.770996 Nanometers)
#   NoData Value=nan
# Band 151 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 151):mosaic_1_2_3) (729.984985 Nanometers)
#   NoData Value=nan
# Band 152 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 152):mosaic_1_2_3) (732.197998 Nanometers)
#   NoData Value=nan
# Band 153 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 153):mosaic_1_2_3) (734.411987 Nanometers)
#   NoData Value=nan
# Band 154 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 154):mosaic_1_2_3) (736.625977 Nanometers)
#   NoData Value=nan
# Band 155 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 155):mosaic_1_2_3) (738.838989 Nanometers)
#   NoData Value=nan
# Band 156 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 156):mosaic_1_2_3) (741.052979 Nanometers)
#   NoData Value=nan
# Band 157 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 157):mosaic_1_2_3) (743.265991 Nanometers)
#   NoData Value=nan
# Band 158 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 158):mosaic_1_2_3) (745.479980 Nanometers)
#   NoData Value=nan
# Band 159 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 159):mosaic_1_2_3) (747.692993 Nanometers)
#   NoData Value=nan
# Band 160 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 160):mosaic_1_2_3) (749.906982 Nanometers)
#   NoData Value=nan
# Band 161 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 161):mosaic_1_2_3) (752.120972 Nanometers)
#   NoData Value=nan
# Band 162 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 162):mosaic_1_2_3) (754.333984 Nanometers)
#   NoData Value=nan
# Band 163 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 163):mosaic_1_2_3) (756.547974 Nanometers)
#   NoData Value=nan
# Band 164 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 164):mosaic_1_2_3) (758.760986 Nanometers)
#   NoData Value=nan
# Band 165 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 165):mosaic_1_2_3) (760.974976 Nanometers)
#   NoData Value=nan
# Band 166 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 166):mosaic_1_2_3) (763.187988 Nanometers)
#   NoData Value=nan
# Band 167 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 167):mosaic_1_2_3) (765.401978 Nanometers)
#   NoData Value=nan
# Band 168 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 168):mosaic_1_2_3) (767.616028 Nanometers)
#   NoData Value=nan
# Band 169 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 169):mosaic_1_2_3) (769.828979 Nanometers)
#   NoData Value=nan
# Band 170 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 170):mosaic_1_2_3) (772.043030 Nanometers)
#   NoData Value=nan
# Band 171 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 171):mosaic_1_2_3) (774.255981 Nanometers)
#   NoData Value=nan
# Band 172 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 172):mosaic_1_2_3) (776.469971 Nanometers)
#   NoData Value=nan
# Band 173 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 173):mosaic_1_2_3) (778.684021 Nanometers)
#   NoData Value=nan
# Band 174 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 174):mosaic_1_2_3) (780.896973 Nanometers)
#   NoData Value=nan
# Band 175 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 175):mosaic_1_2_3) (783.111023 Nanometers)
#   NoData Value=nan
# Band 176 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 176):mosaic_1_2_3) (785.323975 Nanometers)
#   NoData Value=nan
# Band 177 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 177):mosaic_1_2_3) (787.538025 Nanometers)
#   NoData Value=nan
# Band 178 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 178):mosaic_1_2_3) (789.750977 Nanometers)
#   NoData Value=nan
# Band 179 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 179):mosaic_1_2_3) (791.965027 Nanometers)
#   NoData Value=nan
# Band 180 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 180):mosaic_1_2_3) (794.179016 Nanometers)
#   NoData Value=nan
# Band 181 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 181):mosaic_1_2_3) (796.392029 Nanometers)
#   NoData Value=nan
# Band 182 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 182):mosaic_1_2_3) (798.606018 Nanometers)
#   NoData Value=nan
# Band 183 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 183):mosaic_1_2_3) (800.818970 Nanometers)
#   NoData Value=nan
# Band 184 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 184):mosaic_1_2_3) (803.033020 Nanometers)
#   NoData Value=nan
# Band 185 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 185):mosaic_1_2_3) (805.245972 Nanometers)
#   NoData Value=nan
# Band 186 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 186):mosaic_1_2_3) (807.460022 Nanometers)
#   NoData Value=nan
# Band 187 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 187):mosaic_1_2_3) (809.674011 Nanometers)
#   NoData Value=nan
# Band 188 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 188):mosaic_1_2_3) (811.887024 Nanometers)
#   NoData Value=nan
# Band 189 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 189):mosaic_1_2_3) (814.101013 Nanometers)
#   NoData Value=nan
# Band 190 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 190):mosaic_1_2_3) (816.314026 Nanometers)
#   NoData Value=nan
# Band 191 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 191):mosaic_1_2_3) (818.528015 Nanometers)
#   NoData Value=nan
# Band 192 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 192):mosaic_1_2_3) (820.741028 Nanometers)
#   NoData Value=nan
# Band 193 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 193):mosaic_1_2_3) (822.955017 Nanometers)
#   NoData Value=nan
# Band 194 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 194):mosaic_1_2_3) (825.169006 Nanometers)
#   NoData Value=nan
# Band 195 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 195):mosaic_1_2_3) (827.382019 Nanometers)
#   NoData Value=nan
# Band 196 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 196):mosaic_1_2_3) (829.596008 Nanometers)
#   NoData Value=nan
# Band 197 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 197):mosaic_1_2_3) (831.809021 Nanometers)
#   NoData Value=nan
# Band 198 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 198):mosaic_1_2_3) (834.023010 Nanometers)
#   NoData Value=nan
# Band 199 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 199):mosaic_1_2_3) (836.237000 Nanometers)
#   NoData Value=nan
# Band 200 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 200):mosaic_1_2_3) (838.450012 Nanometers)
#   NoData Value=nan
# Band 201 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 201):mosaic_1_2_3) (840.664001 Nanometers)
#   NoData Value=nan
# Band 202 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 202):mosaic_1_2_3) (842.877014 Nanometers)
#   NoData Value=nan
# Band 203 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 203):mosaic_1_2_3) (845.091003 Nanometers)
#   NoData Value=nan
# Band 204 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 204):mosaic_1_2_3) (847.304016 Nanometers)
#   NoData Value=nan
# Band 205 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 205):mosaic_1_2_3) (849.518005 Nanometers)
#   NoData Value=nan
# Band 206 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 206):mosaic_1_2_3) (851.731995 Nanometers)
#   NoData Value=nan
# Band 207 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 207):mosaic_1_2_3) (853.945007 Nanometers)
#   NoData Value=nan
# Band 208 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 208):mosaic_1_2_3) (856.158997 Nanometers)
#   NoData Value=nan
# Band 209 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 209):mosaic_1_2_3) (858.372009 Nanometers)
#   NoData Value=nan
# Band 210 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 210):mosaic_1_2_3) (860.585999 Nanometers)
#   NoData Value=nan
# Band 211 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 211):mosaic_1_2_3) (862.799011 Nanometers)
#   NoData Value=nan
# Band 212 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 212):mosaic_1_2_3) (865.013000 Nanometers)
#   NoData Value=nan
# Band 213 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 213):mosaic_1_2_3) (867.226990 Nanometers)
#   NoData Value=nan
# Band 214 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 214):mosaic_1_2_3) (869.440002 Nanometers)
#   NoData Value=nan
# Band 215 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 215):mosaic_1_2_3) (871.653992 Nanometers)
#   NoData Value=nan
# Band 216 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 216):mosaic_1_2_3) (873.867004 Nanometers)
#   NoData Value=nan
# Band 217 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 217):mosaic_1_2_3) (876.080994 Nanometers)
#   NoData Value=nan
# Band 218 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 218):mosaic_1_2_3) (878.294006 Nanometers)
#   NoData Value=nan
# Band 219 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 219):mosaic_1_2_3) (880.507996 Nanometers)
#   NoData Value=nan
# Band 220 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 220):mosaic_1_2_3) (882.721985 Nanometers)
#   NoData Value=nan
# Band 221 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 221):mosaic_1_2_3) (884.934998 Nanometers)
#   NoData Value=nan
# Band 222 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 222):mosaic_1_2_3) (887.148987 Nanometers)
#   NoData Value=nan
# Band 223 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 223):mosaic_1_2_3) (889.362000 Nanometers)
#   NoData Value=nan
# Band 224 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 224):mosaic_1_2_3) (891.575989 Nanometers)
#   NoData Value=nan
# Band 225 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 225):mosaic_1_2_3) (893.789978 Nanometers)
#   NoData Value=nan
# Band 226 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 226):mosaic_1_2_3) (896.002991 Nanometers)
#   NoData Value=nan
# Band 227 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 227):mosaic_1_2_3) (898.216980 Nanometers)
#   NoData Value=nan
# Band 228 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 228):mosaic_1_2_3) (900.429993 Nanometers)
#   NoData Value=nan
# Band 229 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 229):mosaic_1_2_3) (902.643982 Nanometers)
#   NoData Value=nan
# Band 230 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 230):mosaic_1_2_3) (904.856995 Nanometers)
#   NoData Value=nan
# Band 231 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 231):mosaic_1_2_3) (907.070984 Nanometers)
#   NoData Value=nan
# Band 232 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 232):mosaic_1_2_3) (909.284973 Nanometers)
#   NoData Value=nan
# Band 233 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 233):mosaic_1_2_3) (911.497986 Nanometers)
#   NoData Value=nan
# Band 234 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 234):mosaic_1_2_3) (913.711975 Nanometers)
#   NoData Value=nan
# Band 235 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 235):mosaic_1_2_3) (915.924988 Nanometers)
#   NoData Value=nan
# Band 236 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 236):mosaic_1_2_3) (918.138977 Nanometers)
#   NoData Value=nan
# Band 237 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 237):mosaic_1_2_3) (920.351990 Nanometers)
#   NoData Value=nan
# Band 238 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 238):mosaic_1_2_3) (922.565979 Nanometers)
#   NoData Value=nan
# Band 239 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 239):mosaic_1_2_3) (924.780029 Nanometers)
#   NoData Value=nan
# Band 240 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 240):mosaic_1_2_3) (926.992981 Nanometers)
#   NoData Value=nan
# Band 241 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 241):mosaic_1_2_3) (929.206970 Nanometers)
#   NoData Value=nan
# Band 242 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 242):mosaic_1_2_3) (931.419983 Nanometers)
#   NoData Value=nan
# Band 243 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 243):mosaic_1_2_3) (933.633972 Nanometers)
#   NoData Value=nan
# Band 244 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 244):mosaic_1_2_3) (935.846985 Nanometers)
#   NoData Value=nan
# Band 245 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 245):mosaic_1_2_3) (938.060974 Nanometers)
#   NoData Value=nan
# Band 246 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 246):mosaic_1_2_3) (940.275024 Nanometers)
#   NoData Value=nan
# Band 247 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 247):mosaic_1_2_3) (942.487976 Nanometers)
#   NoData Value=nan
# Band 248 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 248):mosaic_1_2_3) (944.702026 Nanometers)
#   NoData Value=nan
# Band 249 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 249):mosaic_1_2_3) (946.914978 Nanometers)
#   NoData Value=nan
# Band 250 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 250):mosaic_1_2_3) (949.129028 Nanometers)
#   NoData Value=nan
# Band 251 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 251):mosaic_1_2_3) (951.343018 Nanometers)
#   NoData Value=nan
# Band 252 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 252):mosaic_1_2_3) (953.556030 Nanometers)
#   NoData Value=nan
# Band 253 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 253):mosaic_1_2_3) (955.770020 Nanometers)
#   NoData Value=nan
# Band 254 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 254):mosaic_1_2_3) (957.982971 Nanometers)
#   NoData Value=nan
# Band 255 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 255):mosaic_1_2_3) (960.197021 Nanometers)
#   NoData Value=nan
# Band 256 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 256):mosaic_1_2_3) (962.409973 Nanometers)
#   NoData Value=nan
# Band 257 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 257):mosaic_1_2_3) (964.624023 Nanometers)
#   NoData Value=nan
# Band 258 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 258):mosaic_1_2_3) (966.838013 Nanometers)
#   NoData Value=nan
# Band 259 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 259):mosaic_1_2_3) (969.051025 Nanometers)
#   NoData Value=nan
# Band 260 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 260):mosaic_1_2_3) (971.265015 Nanometers)
#   NoData Value=nan
# Band 261 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 261):mosaic_1_2_3) (973.478027 Nanometers)
#   NoData Value=nan
# Band 262 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 262):mosaic_1_2_3) (975.692017 Nanometers)
#   NoData Value=nan
# Band 263 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 263):mosaic_1_2_3) (977.905029 Nanometers)
#   NoData Value=nan
# Band 264 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 264):mosaic_1_2_3) (980.119019 Nanometers)
#   NoData Value=nan
# Band 265 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 265):mosaic_1_2_3) (982.333008 Nanometers)
#   NoData Value=nan
# Band 266 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 266):mosaic_1_2_3) (984.546021 Nanometers)
#   NoData Value=nan
# Band 267 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 267):mosaic_1_2_3) (986.760010 Nanometers)
#   NoData Value=nan
# Band 268 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 268):mosaic_1_2_3) (988.973022 Nanometers)
#   NoData Value=nan
# Band 269 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 269):mosaic_1_2_3) (991.187012 Nanometers)
#   NoData Value=nan
# Band 270 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 270):mosaic_1_2_3) (993.400024 Nanometers)
#   NoData Value=nan
# Band 271 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 271):mosaic_1_2_3) (995.614014 Nanometers)
#   NoData Value=nan
# Band 272 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 272):mosaic_1_2_3) (997.828003 Nanometers)
#   NoData Value=nan
# Band 273 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 273):mosaic_1_2_3) (1000.039978 Nanometers)
#   NoData Value=nan
# Band 274 Block=613x1 Type=Float32, ColorInterp=Undefined
#   Description = Layer (Mosaic (Band 274):mosaic_1_2_3) (1002.250000 Nanometers)
#   NoData Value=nan

# %% [markdown]
# ### **2.3 Sistema de Referência de Coordenadas (SRC/CRS)**
#
# | EPSG | Nome | Tipo | Uso comum |
# |---|---|---|---|
# | `4326` | WGS 84 | Geográfico (lat/lon) | Dados globais, GPS, APIs, interoperabilidade |
# | `4674` | SIRGAS 2000 | Geográfico (lat/lon) | Base nacional para IBGE, cartografia, dados oficiais |
# | `3857` | WGS 84 / Pseudo-Mercator | Projetado | Mapas web (Google Maps, OpenStreetMap, Leaflet) |
# | `31980` | SIRGAS 2000 / UTM zone 20S | Projetado | Mato Grosso, Rondônia, Amazonas, Roraima|
# | `31981` | SIRGAS 2000 / UTM zone 21S | Projetado | Mato Grosso do Sul, Pará|
# | `31982` | SIRGAS 2000 / UTM zone 22S | Projetado | Amapá, Pará, Tocantins, Goiás, São Paulo, Paraná, Santa Catarina, Rio Grande do Sul |
# | `31983` | SIRGAS 2000 / UTM zone 23S | Projetado | Rio de Janeiro, Minas, Maranhão, Bahia  |
# | `31984` | SIRGAS 2000 / UTM zone 24S | Projetado | Espírito Santo, Bahia, Ceará, Pernambuco, Paraíba, Rio Grande do Norte |

# %% [markdown]
# ## 3. Identificar datasets públicos
#
# Há uma vasta quantidade de dados geoespaciais disponíveis publicamente. Os principais repositórios estão sempre em constante transformações, outros vão ficando obsoletos ao longo do tempo, sendo importante se atualizar constantemente sobre o que há de novo em disponibilização de geoinformação.
#
# ### **3.1 Portais Brasileiros**
#
# | Portal | URL | Conteúdo |
# |--------|-----|----------|
# | **IBGE** | https://geoftp.ibge.gov.br | Malhas municipais, censo, estatísticas |
# | **IBGE API** | https://servicodados.ibge.gov.br | Dados censitários via API REST |
# | **INPE** | http://queimadas.dgi.inpe.br <br> https://data.inpe.br/bdc/ | Focos de queimadas e imagens |
# | **INDE** | https://www.inde.gov.br | Infraestrutura Nacional de Dados Espaciais |
# | **BDGEX** | https://bdgex.eb.mil.br/bdgexapp | Base de dados geoespaciais do Exército Brasileiro |
# | **dados.gov.br** | https://dados.gov.br | Portal central de dados abertos do governo |

# %% [markdown]
# ### **3.2 Portais Internacionais**
#
# | Portal | URL | Conteúdo |
# |--------|-----|----------|
# | **OpenStreetMap** | https://www.openstreetmap.org | Mapa colaborativo global (ruas, edificações, POIs) |
# | **NASA EarthData** | https://earthdata.nasa.gov | Imagens de satélite, clima, oceanos |
# | **Copernicus (ESA)** | https://www.copernicus.eu | Sentinel, dados ambientais, Europa e global |
# | **Our World in Data** | https://ourworldindata.org | Dados socioeconômicos globais com API |

# %% [markdown]
# ### **3.3 Exemplo: Baixando Malha Municipal do IBGE**

# %%
import requests
import geopandas as gpd

url = (
    "https://geoftp.ibge.gov.br/organizacao_do_territorio/malhas_territoriais"
    "/malhas_municipais/municipio_2022/Brasil/BR/BR_Municipios_2022.zip"
)

local_path = "BR_Municipios_2022.zip"
if not os.path.exist(local_path):
    with requests.get(url, stream=True) as resposta:
        resposta.raise_for_status()
        with open(local_path, "wb") as f:
            for bloco in resposta.iter_content(chunk_size=8192):
                f.write(bloco)
    print(f"Download concluído: {local_path}")
    
municipios = gpd.read_file(local_path) # geopandas suporta leitura de .zip
# Out:
# Download concluído: BR_Municipios_2022.zip

# %% [markdown]
# **Plot**

# %%
import matplotlib.pyplot as plt

municipios.plot(figsize=(5, 4), edgecolor='gray', linewidth=0.3); plt.show()

# %% [markdown]
# **Tabela de atributos**

# %%
municipios.head()
# Out:
#     CD_MUN                 NM_MUN SIGLA_UF  AREA_KM2  \
# 0  1100015  Alta Floresta D'Oeste       RO  7067.127
# 1  1100023              Ariquemes       RO  4426.571
# 2  1100031                 Cabixi       RO  1314.352
# 3  1100049                 Cacoal       RO  3793.000
# 4  1100056             Cerejeiras       RO  2783.300
#
#                                             geometry
# 0  POLYGON ((-62.00806 -12.13379, -62.00784 -12.2...
# 1  POLYGON ((-63.17933 -10.13924, -63.17746 -10.1...
# 2  POLYGON ((-60.52408 -13.32137, -60.37162 -13.3...
# 3  POLYGON ((-61.35502 -11.50452, -61.35524 -11.5...
# 4  POLYGON ((-60.82135 -13.1191, -60.81773 -13.12...

# %% [markdown]
# **Filtragem no Geopandas**

# %%
niteroi_lim = municipios[municipios.NM_MUN == "Niterói"].geometry.values[0]
niteroi_lim
# Out:
# <MULTIPOLYGON (((-43.073 -22.957, -43.074 -22.957, -43.075 -22.956, -43.076 ...>

# %% [markdown]
# ### **3.4 OpenStreetMap (OSM)**
#
# <img src="media/imgs/OSM-modelo-conceitual.png">

# %% [markdown]
# ### **3.4 OpenStreetMap (OSM)**
#
# OSM representa o mundo por meio de grafos com [três tipos de elementos fundamentais](https://wiki.openstreetmap.org/wiki/Elements#Common_attributes):
#
# - pontos (*nodes*)
# - linhas/polígonos (*ways*)
# - estruturas relacionais (*relations*): entre *nodes*, *ways*, e/ou outros *relations*
#
# Todos podem ter **tags** associadas que descrevem seu significado (ex.: `highway=traffic_signals`).

# %% [markdown]
# ## 4. Conceituar API e como ser cliente de uma API
#
# ### **4.1 O que é uma API?**
#
# **API** (*Application Programming Interface*) é um conjunto de regras e protocolos que permite que dois sistemas de software se comuniquem. Em ciência de dados, usamos principalmente **APIs Web** baseadas no protocolo HTTP.
#
# ```
#          Requisição HTTP (GET /dados?municipio=3304557)
# Cliente ────────────────────────────────────────────────▶ Servidor (API)
#         ◀────────────────────────────────────────────────
#               Resposta HTTP 200 OK  {"populacao": 515317}
# ```

# %% [markdown]
# ### **4.2 Anatomia de uma URL de API**
#
# ```
# https://servicodados.ibge.gov.br/api/v1/localidades/municipios/3304557
# │──────────────────────────────────────│──────────────────────│───────│
#          Base URL                            Endpoint          Parâmetro
#                                             (recurso)          (código IBGE)
# ```

# %% [markdown]
# ### **4.3 Métodos HTTP mais comuns**
#
# | Método | Uso | Analogia |
# |--------|-----|----------|
# | `GET` | Buscar/ler dados | Consultar uma ficha |
# | `POST` | Enviar/criar dados | Preencher um formulário |
# | `PUT` | Atualizar dados | Substituir uma ficha |
# | `DELETE` | Remover dados | Apagar um registro |
#
# <br>
#
# > Em **ciência de dados**, usamos quase exclusivamente `GET`, pois apenas queremos *ler* dados.

# %% [markdown]
# ### **4.4 Códigos de Status HTTP**
#
# | Código | Significado |
# |--------|-------------|
# | `200 OK` | Sucesso |
# | `400 Bad Request` | Parâmetro inválido na requisição |
# | `401 Unauthorized` | Autenticação necessária (API Key) |
# | `403 Forbidden` | Sem permissão de acesso |
# | `404 Not Found` | Recurso não encontrado |
# | `429 Too Many Requests` | Limite de requisições atingido |
# | `500 Internal Server Error` | Erro no servidor |

# %% [markdown]
# ### **4.5 Formatos de Resposta**
#
# A maioria das APIs retorna dados em **JSON** (*JavaScript Object Notation*):
#
# ```json
# {
#   "id": 3304557,
#   "nome": "Niterói",
#   "microrregiao": {
#     "id": 33009,
#     "nome": "Rio de Janeiro"
#   }
# }
# ```
#
# APIs geoespaciais frequentemente retornam **GeoJSON**:
#
# ```json
# {
#   "type": "Feature",
#   "geometry": {
#     "type": "Point",
#     "coordinates": [-43.1033, -22.8832]
#   },
#   "properties": {
#     "nome": "Niterói",
#     "populacao": 515317
#   }
# }
# ```

# %% [markdown]
# ### **4.6 Autenticação**
#
# Muitas APIs exigem uma **chave de acesso (API Key)** para controle de uso:
#
# ```python
# # Exemplos de autenticação
#
# # 1. Via parâmetro na URL
# url = "https://api.exemplo.com/dados?api_key=SUA_CHAVE"
#
# # 2. Via cabeçalho (header) HTTP
# headers = {"Authorization": "Bearer SUA_CHAVE"}
# response = requests.get(url, headers=headers)
#
# # Boas práticas: NUNCA coloque a chave diretamente no código!
# import os
# api_key = os.environ.get("MINHA_API_KEY")  # Correto
# api_key = "abc123xyz"                      # Evitar
# ```

# %% [markdown]
# ### **4.7 Ferramentas para efetuar requisições para uma API**
#
# Em Python, a biblioteca padrão para fazer requisições HTTP é a `requests`. Porém, a depender do serviço, existem bibliotecas que já possuem métodos para fazer a comunicação com a API. Pode-se citar:
#
# - [cbers4asat](https://pypi.org/project/cbers4asat/): Biblioteca Python para realizar a busca e processamento de imagens dos satélites CBERS-04A e AMAZONIA-1
# - [OSMnx](https://osmnx.readthedocs.io/en/stable/index.html): Pacote em Python para baixar, modelar, analisar e visualizar facilmente redes de ruas e outras características geoespaciais do OpenStreetMap.
# - [Sentinel Hub](https://sentinelhub-py.readthedocs.io/en/latest/index.html): Serviço de imagens de satélite de big data multiespectral e multi-temporal. Os usuários podem usar a API do Sentinel Hub para recuperar dados de satélite em seus AOI e intervalos de tempo específicos.
# - [CopernicusAPI](https://pypi.org/project/copernicusapi/): Um pacote para facilitar a construção interativa de consultas para o repositório do Ecossistema Copernicus Data Space.
# - [geobr](https://github.com/ipeaGIT/geobr): Pacote R ou Python para baixar conjuntos oficiais do Instituto de Pesquisa Econômica Aplicada (Ipea) de dados espaciais do Brasil.
#
# > Sempre deve-se estar atento quanto a atualização dessas bibliotecas.

# %% [markdown]
# ### **4.8 Exemplo: API do IBGE (Localidades)**

# %%
# API do IBGE - Localidades
# Documentação: https://servicodados.ibge.gov.br/api/docs/localidades
import requests
import json

# Endpoint da API de Localidades do IBGE
base, endpoint, params = "https://servicodados.ibge.gov.br/api/v1", "/localidades", "/municipios/3304557"

# Fazendo a requisição GET
url = base + endpoint + params
resposta = requests.get(url)
print(f"Status HTTP: {resposta.status_code}")
# Parseando o JSON retornado
dados = resposta.json()
print(json.dumps(dados, indent=2, ensure_ascii=False))
# Out:
# Status HTTP: 200
# {
#   "id": 3304557,
#   "nome": "Rio de Janeiro",
#   "microrregiao": {
#     "id": 33018,
#     "nome": "Rio de Janeiro",
#     "mesorregiao": {
#       "id": 3306,
#       "nome": "Metropolitana do Rio de Janeiro",
#       "UF": {
#         "id": 33,
#         "sigla": "RJ",
#         "nome": "Rio de Janeiro",
#         "regiao": {
#           "id": 3,
#           "sigla": "SE",
#           "nome": "Sudeste"
#         }
#       }
#     }
#   },
#   "regiao-imediata": {
#     "id": 330001,
#     "nome": "Rio de Janeiro",
#     "regiao-intermediaria": {
#       "id": 3301,
#       "nome": "Rio de Janeiro",
#       "UF": {
#         "id": 33,
#         "sigla": "RJ",
#         "nome": "Rio de Janeiro",
#         "regiao": {
#           "id": 3,
#           "sigla": "SE",
#           "nome": "Sudeste"
#         }
#       }
#     }
#   }
# }

# %% [markdown]
# ### **4.9 Exemplo: API SIDRA — Censo 2022 (população por UF)**

# %%
# Documentação: https://apisidra.ibge.gov.br/
import requests

url_sidra = "https://apisidra.ibge.gov.br/values/t/9514/n6/all/v/93/p/2022/d/v93 0"
resposta = requests.get(url_sidra)
resposta_dict = resposta.json()

print(f"Tamanho da resposta:\t {len(resposta_dict)}")
print("Cabeçalho:\t", resposta_dict[0])
print("Primeiro dado:")
print(json.dumps(resposta_dict[1], indent=2, ensure_ascii=False))
# Out:
# Tamanho da resposta:	 5571
# Cabeçalho:	 {'NC': 'Nível Territorial (Código)', 'NN': 'Nível Territorial', 'MC': 'Unidade de Medida (Código)', 'MN': 'Unidade de Medida', 'V': 'Valor', 'D1C': 'Município (Código)', 'D1N': 'Município', 'D2C': 'Variável (Código)', 'D2N': 'Variável', 'D3C': 'Ano (Código)', 'D3N': 'Ano', 'D4C': 'Sexo (Código)', 'D4N': 'Sexo', 'D5C': 'Forma de declaração da idade (Código)', 'D5N': 'Forma de declaração da idade', 'D6C': 'Idade (Código)', 'D6N': 'Idade'}
# Primeiro dado:
# {
#   "NC": "6",
#   "NN": "Município",
#   "MC": "45",
#   "MN": "Pessoas",
#   "V": "21494",
#   "D1C": "1100015",
#   "D1N": "Alta Floresta D'Oeste - RO",
#   "D2C": "93",
#   "D2N": "População residente",
#   "D3C": "2022",
#   "D3N": "2022",
#   "D4C": "6794",
#   "D4N": "Total",
#   "D5C": "113635",
#   "D5N": "Total",
#   "D6C": "100362",
#   "D6N": "Total"
# }

# %% [markdown]
# ### **4.10 Exemplo: Biblioteca OSMnx**
#
# Permite a análise de redes de ruas.

# %%
import osmnx as ox

# baixar a rede viária de Niterói e onversão para GeoDataFrame
G = ox.graph_from_place("Niterói, Brasil", network_type="drive")
gdf_nodes, gdf_edges = ox.graph_to_gdfs(G)

print(f"Número de nós: {len(gdf_nodes)}")
print(f"Número de arestas: {len(gdf_edges)}")
# Out:
# Número de nós: 6777
# Número de arestas: 15196

# %% [markdown]
# **Plotagem da rede viária**

# %%
import matplotlib.pyplot as plt
import contextily as cx
import geopandas as gpd

fig, ax = plt.subplots(figsize=(5, 3))
gdf_nodes.plot(ax=ax, markersize=3, label='Nós') 
gdf_edges.plot(ax=ax, linewidth=0.5, color='red', label='Arestas')
gpd.GeoDataFrame([niteroi_lim], columns=['geometry']).plot(ax=ax, color='none', edgecolor='black', linewidth=1, label='Limite de Niterói')

ax.set_title("Rede Viária de Niterói", fontsize=9)
cx.add_basemap(ax, crs=gdf_edges.crs.to_string(), source=cx.providers.OpenStreetMap.Mapnik)
plt.show()

# %% [markdown]
# ### **4.11 Exemplo: Overpass API (OpenStreetMap)**
#
# A **Overpass API** permite consultar dados do OpenStreetMap com uma linguagem de query própria, a [Overpass QL (Query Language)](https://wiki.openstreetmap.org/wiki/Overpass_API).
#
# ```javascript
# // resposta em json, de todos os ways com tag highway=motorway dentro do bbox:
# [out:json][timeout:180];
# (
#     way["highway=motorway"](-22,-43,-22,-42);
# );
# (._;>;);
# out body;
# ```

# %%
import requests

# Consulta Overpass: ruas em Niterói-RJ
overpass_url = "https://overpass.private.coffee/api/interpreter"

highway_types = "motorway|motorway_link|trunk|trunk_link|primary|primary_link|secondary|secondary_link|tertiary|unclassified|residential|service|living_street|track"
bbox_str = f"{niteroi_lim.bounds[1]},{niteroi_lim.bounds[0]},{niteroi_lim.bounds[3]},{niteroi_lim.bounds[2]}"

# Overpass QL (Query Language)
query = f"""
    [out:json][timeout:180];
    (
      way["highway"~"^({highway_types})$"]({bbox_str});
    );
    (._;>;);
    out body;
    """
# (._;>;); significa:
# ._ = elemento atual (as ways)
# > = todos os nodes referenciados pelas ways
# out body; = retorna os objetos completos
headers = {
        "User-Agent": "MeuNavegador/1.0 (aula IME)",
    }

resposta = requests.post(overpass_url, data={"data": query},
                          headers=headers, timeout=180)
resposta.raise_for_status()  # Verificar se a requisição foi bem-sucedida
dados = resposta.json()

# %%
nodes = [el for el in dados['elements'] if el['type'] == 'node']
ways = [el for el in dados['elements'] if el['type'] == 'way']

print("Quantidade de ways:", len(ways))
print("Quantidade de nodes:", len(nodes))
print("Primeira way:", ways[0])
print("Primeiro node:", nodes[0], "\n")
for node_id in ways[0]['nodes']:
    node = next((el for el in nodes if el['id'] == node_id), None)
    if node:
        print(f"Node {node_id}: {node['lat']}, {node['lon']}")
# Out:
# Quantidade de ways: 10766
# Quantidade de nodes: 68588
# Primeira way: {'type': 'way', 'id': 16135695, 'nodes': [3227865728, 5070470047, 8866407570], 'tags': {'highway': 'motorway', 'lanes': '3', 'lit': 'yes', 'maxspeed': '80', 'name': 'Avenida do Contorno', 'official_name': 'Rodovia Governador Mário Covas', 'oneway': 'yes', 'ref': 'BR-101', 'surface': 'asphalt'}}
# Primeiro node: {'type': 'node', 'id': 34580131, 'lat': -22.8728952, 'lon': -43.1364278}
#
# Node 3227865728: -22.876001, -43.1102805
# Node 5070470047: -22.8755092, -43.1102054
# Node 8866407570: -22.875331, -43.1101769

# %% [markdown]
# ## Lista de exercícios
#
# **Exercício 1.** Acesse a API do IBGE (`servicodados.ibge.gov.br`) e obtenha a lista de todos os municípios do estado do Rio de Janeiro. Quantos são?
#
# **Exercício 2.** Utilizando a API SIDRA do IBGE (tabela 9514), obtenha a população de todos os municípios fluminenses no Censo 2022. Qual o município mais populoso? E o menos populoso?
#
# **Exercício 3.** Faça o download da malha municipal do estado do RJ via `geoftp.ibge.gov.br`. Plote um mapa colorindo os municípios por população (use os dados do Exercício 2).
#
# **Exercício 4.** Usando a Overpass API, obtenha a localização de todas as escolas (`amenity=school`) da cidade de Niterói. Quantas foram encontradas? Plote-as em um mapa.

# %% [markdown]
# ## 5. Conceituar a especificação de Geosserviços OGC
#
# ### **5.1 O que são geosserviços com o padrão do Open Geospatial Consortium (OGC)**
#
# São serviços web que permitem coletar, armazenar, recuperar, transformar e apresentar dados espaciais, por meio do acesso a um link (URL) disponibilizado por um servidor. Os 3 padrões de geosserviços definidos pela OGC são
#
# - **Web Map Service (WMS):** geosserviço para baixar uma representação visual de dados espaciais;
# - **Web Feature Service (WFS):** permite baixar os dados geoespaciais vetoriais.
# - **Web Coverage Service (WCS):** permite baixar um conjunto de dados em formato matricial, usado para representar fenômenos com variações ao longo do tempo.

# %% [markdown]
# ### **5.2 Anatomia de uma URL de geosserviço**
#
# <div>
# <style>
#     .p-service{background: #CEBBF6; color: #26215C; padding: 2px 5px; border-radius: 4px;}
#     .p-version{background: #9FE1CB; color: #04342C; padding: 2px 5px; border-radius: 4px;}
#     .p-request{background: #F0997B; color: #4A1B0C; padding: 2px 5px; border-radius: 4px;}
#     .p-layer{background: #B5D4F4; color: #042C53; padding: 2px 5px; border-radius: 4px;}
#     .p-bbox{background: #FAC775; color: #412402; padding: 2px 5px; border-radius: 4px;}
#     .p-extra{background: #F4C0D1; color: #4B1528; padding: 2px 5px; border-radius: 4px;}
#     .p-output{background: #C0DD97; color: #173404; padding: 2px 5px; border-radius: 4px;}
# </style>
#  <span>https://geoservicos.ibge.gov.br/geoserver/ows?</span>
#  <span class="p-service">SERVICE=WFS</span>&amp;
#  <span class="p-version">VERSION=2.0.0</span>&amp;
#  <span class="p-request">REQUEST=GetFeature</span>&amp;
#  <span class="p-layer">TYPENAMES=CGEO:municipio</span>&amp;
#  <span class="p-bbox">SRSNAME=EPSG:4326</span>&amp;
#  <span class="p-extra">COUNT=50</span>&amp;
#  <span class="p-output">OUTPUTFORMAT=application/json</span>
#
#  <ul>
# <li><span class="p-service">SERVICE=WFS</span>: Identifica o protocolo. WFS entrega feições geométricas com atributos, não imagens.</li>
# <li><span class="p-version">VERSION=2.0.0</span>: Versão do protocolo OGC WFS. 2.0.0 é a mais atual; 1.0.0 e 1.1.0 ainda existem.</li>
# <li><span class="p-request">REQUEST=GetFeature</span>: Operação solicitada. Use GetCapabilities para descobrir camadas disponíveis.</li>
# <li><span class="p-layer">TYPENAMES=CGEO:municipio</span>: Nome da camada (workspace:layer no GeoServer). Obrigatório em GetFeature.</li>
# <li><span class="p-bbox" >SRSNAME=EPSG:4326</span>: Sistema de referência de coordenadas das feições retornadas. WGS-84 é o mais comum.</li>
# <li><span class="p-extra" >COUNT=50</span>:Limita o número de feições retornadas. Importante para não sobrecarregar os servidores e clientes.</li>
# <li><span class="p-output">OUTPUTFORMAT=application/json</span>: Formato de saída. GeoJSON é o mais compatível com Python/GeoPandas.</li>
# </ul>
# </div>

# %% [markdown]
# ### **5.3 Extrato de URLs de geosserviços**
#
# https://inde.gov.br/CatalogoGeoservicos
#
# <img src="media/imgs/inde-ows.jpeg">

# %% [markdown]
# ### **5.4 Exemplo: Serviços OGC da DSG**
#
# Geosserviços da DSG disponíveis em: https://geoportal.eb.mil.br/portal/index.php/bdgex/servicos-ogc
#
# **1º Passo**: Antes de fazer qualquer requisição, sempre comece com `GetCapabilities` — ele retorna um XML descrevendo todas as camadas disponíveis, sistemas de coordenadas suportados e formatos de saída:
#
# <img src="media/imgs/bdgex-GetCapabilities.png" height=400>

# %% [markdown]
# ### **5.4 Exemplo: Serviços OGC da DSG**

# %%
import requests
from bs4 import BeautifulSoup

url = "http://bdgex.eb.mil.br/ms25/ows?SERVICE=WFS&REQUEST=GetCapabilities"
response = requests.get(url) # Fazer a requisição

soup = BeautifulSoup(response.content, 'xml') # Parsear o XML
feature_types = soup.find_all('FeatureType') # Capturar as tags FeatureType

print(f"Total de FeatureTypes encontrados: {len(feature_types)}")
for i, ft in enumerate(feature_types, 1):
    print(f"{i}: {ft.find('Name').text} ({ft.find('Title').text})")
    if i >= 8: break
# Out:
# Total de FeatureTypes encontrados: 397
# 1: ms:Trecho_Massa_Dagua_A (Trecho_Massa_Dagua_A)
# 2: ms:Edif_Saude_A (Edif_Saude_A)
# 3: ms:Cidade_P (Cidade_P)
# 4: ms:Identificador_Trecho_Rodoviario_P (Identificador_Trecho_Rodoviario_P)
# 5: ms:Galeria_Bueiro_P (Galeria_Bueiro_P)
# 6: ms:Area_Edificada_A (Area_Edificada_A)
# 7: ms:Nome_Local_P (Nome_Local_P)
# 8: ms:Trecho_Drenagem_L (Trecho_Drenagem_L)

# %% [markdown]
# ### **5.4 Exemplo: Serviços OGC da DSG**
#
# **2º Passo**: Montagem da url da requisição

# %%
from urllib.parse import urlencode

# Parâmetros da requisição
params = {
    "SERVICE": "WFS",
    "VERSION": "2.0.0",
    "REQUEST": "GetFeature",
    "TYPENAMES": "ms:Trecho_Massa_Dagua_A", # camada
    "SRSNAME": "EPSG:4326",
    "COUNT": 100,                          # limite de feições
    "OUTPUTFORMAT": "application/gml+xml; version=3.2",
    # Filtro espacial por BBOX (minX, minY, maxX, maxY)
    "BBOX": "-125, -55, 0, 15,EPSG:4326",
}
base_url = 'http://bdgex.eb.mil.br/ms25/ows'
url = f"{base_url}?{urlencode(params)}"
print("URL da requisição WFS:")
print(url)
# Out:
# URL da requisição WFS:
# http://bdgex.eb.mil.br/ms25/ows?SERVICE=WFS&VERSION=2.0.0&REQUEST=GetFeature&TYPENAMES=ms%3ATrecho_Massa_Dagua_A&SRSNAME=EPSG%3A4326&COUNT=100&OUTPUTFORMAT=application%2Fgml%2Bxml%3B+version%3D3.2&BBOX=-125%2C+-55%2C+0%2C+15%2CEPSG%3A4326

# %% [markdown]
# ### **5.4 Exemplo: Serviços OGC da DSG**
#
# **3º Passo**: Requisição do dado

# %%
import geopandas as gpd
import requests
import io

requests.packages.urllib3.disable_warnings()
response = requests.get(url, verify=False)

# Load the content into GeoPandas
gdf = gpd.read_file(io.BytesIO(response.content))
gdf.head(1)
# Out:
#                       gml_id            lowerCorner            upperCorner  \
# 0  Trecho_Massa_Dagua_A.3458  -25.384451 -49.428789  -25.384028 -49.427876
#
#     gid  geometriaAproximada tipoMassaDagua      regime    salinidade  \
# 0  3458                  0.0   Desconhecida  Permanente  Desconhecida
#
#   tipoTrechoMassa                            metadataid nomeAbrev  nome  \
# 0   Represa/Açude  a1837703-efc9-5576-5eb1-ed2597e9f4a2      None  None
#
#                                             geometry
# 0  POLYGON ((-49.42788 -25.3841, -49.42788 -25.38...

# %% [markdown]
# ## 6. Conceituar a especificação de catalogação STAC
#
# **STAC** (SpatioTemporal Asset Catalog) é uma especificação aberta para catalogar dados geoespaciais de forma padronizada, facilitando a descoberta, busca e acesso a grandes volumes de imagens de satélite, dados de sensoriamento remoto e qualquer dado com dimensão espacial e temporal.
#
# Desde sua origem em 2021, vem resolvendo o problema de cada provedor ter formatos e APIs incompatíveis entre si.
#
# **Catálogos abertos importantes:**
#
# - https://planetarycomputer.microsoft.com/api/stac/v1
# - https://earth-search.aws.element84.com/v1
# - https://landsatlook.usgs.gov/stac-server
# - https://catalogue.dataspace.copernicus.eu/stac

# %% [markdown]
# ### **6.1 Exemplo: Listar as coleções dentro de um catálogo**

# %%
from pystac_client import Client

# Conecta ao Microsoft Planetary Computer
# https://planetarycomputer.microsoft.com/catalog
client = Client.open(
    "https://planetarycomputer.microsoft.com/api/stac/v1",
)

# Lista todas as coleções disponíveis
for i, collection in enumerate(client.get_collections()):
    print(f"{i}: {collection.id} — {collection.title}")
    if i >= 10: break
# Out:
# 0: daymet-annual-pr — Daymet Annual Puerto Rico
# 1: daymet-daily-hi — Daymet Daily Hawaii
# 2: 3dep-seamless — USGS 3DEP Seamless DEMs
# 3: 3dep-lidar-dsm — USGS 3DEP Lidar Digital Surface Model
# 4: fia — Forest Inventory and Analysis
# 5: gridmet — gridMET
# 6: daymet-annual-na — Daymet Annual North America
# 7: daymet-monthly-na — Daymet Monthly North America
# 8: daymet-annual-hi — Daymet Annual Hawaii
# 9: daymet-monthly-hi — Daymet Monthly Hawaii
# 10: daymet-monthly-pr — Daymet Monthly Puerto Rico

# %% [markdown]
# ### **6.2 Exemplo: Listar os itens dentro de uma coleção**

# %%
from shapely.geometry import shape
import geopandas as gpd

# Busca por imagens RADAR Sentinel-1 GRD (Ground Range Detected)
# com modo de instrumento IW (Interferometric Wide swath)
# https://browser.stac.dataspace.copernicus.eu/?.language=pt
catalog = Client.open("https://catalogue.dataspace.copernicus.eu/stac")
search = catalog.search(
    collections=["sentinel-1-grd"],   # coleções de interesse
    bbox=[ -55, -2.5, -54.5, -2],     # [top-left, bottom-right] of aoi polygon
    datetime="2025-01-01/2026-01-01",
    query={ "sar:instrument_mode": {"eq": "IW"} }
)
items = list(search.items())
print("Quantidade de imagens S1 encontradas:", len(items))
# Out:
# Quantidade de imagens S1 encontradas: 55

# %% [markdown]
# ### **6.2 Exemplo: Listar os itens dentro de uma coleção**

# %%
from IPython.display import display

# Manipulação de dados para um GeoDataFrame
data, geoms, total_size =  [], [], 0
for item in items:
  geoms.append( shape(item.geometry) )
  size = int(item.assets["Product"].extra_fields["file:size"])
  total_size += size
  data.append([item.id, item.datetime, item.assets["Product"].href, f"{int(size/1024**2)} Mb" ])
s1_gdf = gpd.GeoDataFrame(data, columns=["nome","data","href","file_size"], geometry=geoms)
s1_gdf.set_crs(epsg=4326, inplace=True)

print("Espaço das imagens S1 encontradas:", f"{int(total_size/1024**3)} Gb")
display(s1_gdf.head(1))
# Out:
# Espaço das imagens S1 encontradas: 63 Gb
#                                                 nome  \
# 0  S1A_IW_GRDH_1SDV_20251221T092257_20251221T0923...
#
#                               data  \
# 0 2025-12-21 09:22:57.112189+00:00
#
#                                                 href file_size  \
# 0  https://download.dataspace.copernicus.eu/odata...   1172 Mb
#
#                                             geometry
# 0  POLYGON ((-54.41539 -3.77114, -56.68392 -3.272...

# %% [markdown]
# ### **6.2 Exemplo: Listar os itens dentro de uma coleção**

# %%
import contextily as cx

# Plot the GeoDataFrame with an OSM background
ax2 = s1_gdf.plot(figsize=(5, 4), edgecolor='red', facecolor="none",  linewidth=1)
cx.add_basemap(ax2, crs=s1_gdf.crs.to_string(), source=cx.providers.OpenStreetMap.Mapnik)

# %% [markdown]
# ### **6.3 Exemplo: Download dos assets dentro de um item**

# %%
import requests

# Para este passo, deve-se possuir um login: https://dataspace.copernicus.eu/

# Run write one time with Copernicus Data Space Ecosystem (CDSE) credentials
# with open('copernicus_cred.txt', 'w', encoding='utf-8') as file:
#   file.write("email:senha")

## Open file in read-only mode
with open('copernicus_cred.txt', 'r', encoding='utf-8') as file:
  txt = file.read()
  username, password = txt.split(":")

token_url = "https://identity.dataspace.copernicus.eu/auth/realms/CDSE/protocol/openid-connect/token"
data = {
    "client_id": "cdse-public",
    "username": username,
    "password": password,
    "grant_type": "password"
}
token = requests.post(token_url, data=data).json()["access_token"]
headers = {"Authorization": f"Bearer {token}"}

# %% [markdown]
# ### **6.3 Exemplo: Download dos assets dentro de um item**

# %%
import os 
for row in s1_gdf.iterrows():
    filename = row[1]["nome"]+".zip"
    asset_url = row[1]["href"]
    print(f"Downloading {asset_url}...")
    r = requests.get(asset_url, headers=headers, stream=True)
    if r.status_code == 200:
        with open(filename, "wb") as f:
            for chunk in r.iter_content(8192):
                f.write(chunk)
    elif r.status_code == 401:
        print(f"Erro ao baixar {filename}: Token vencido")
    else:
        print(f"Erro ao baixar {filename}: {r.status_code}")
    print(f"{filename} baixado com sucesso.")
    break
# Out:
# Downloading https://download.dataspace.copernicus.eu/odata/v1/Products(df32b8ea-1579-4592-94ec-94b242c5db01)/$value...
# S1A_IW_GRDH_1SDV_20251221T092257_20251221T092322_062411_07D166_AC8A_COG.zip baixado com sucesso.

# %% [markdown]
# ## 7. Web scraping: obtendo dados sem API
#
# Muitos portais de dados abertos disponibilizam apenas páginas web, sem oferecer API estruturada. Nestes casos, se utiliza a técnica de web scraping para **extrair o dado de dentro do HTML da página**.
#
# <img src="media/imgs/matrix.png">

# %% [markdown]
# ### **7.1 Aviso de atenção ética e legal**
#
# - Não há nada inerentemente ilegal sobre o web scraping.
# - Porém, quando se trata de **dados pessoais e propriedade intelectual, o web scraping pode rapidamente se transformar em web scraping mal-intencionado**, sujeito a leis de proteção de dados.
# - Arquivo `robots.txt`: Esse arquivo permite que o dono do site diga aos scrapers, crawlers e outros bots o que eles podem e não podem acessar.
# - Use preferencialmente APIs quando disponíveis.
#
# **Bibliotecas principais**
#
# | Biblioteca | Uso |
# |-----------|-----|
# | `requests` | Buscar o HTML da página |
# | `BeautifulSoup` | Parsear e navegar o HTML |
# | `selenium` | Controlar navegador (páginas com JavaScript) |
# | `scrapy` | Framework completo para scraping em escala |

# %% [markdown]
# ### **7.2 Exemplo: Basic HTML Data Extraction**
#
# A página [TryScrapeMe](https://tryscrapeme.com/) contém alguns desafios ilustrativos.
#
# ```txt
# Desafio 1: https://tryscrapeme.com/web-scraping-practice/beginner/abc
# Calculate the total value of the price column from the scraped data.
# ```
#
# **1º passo**: verificar `robots.txt` em https://tryscrapeme.com/robots.txt

# %% [markdown]
# ### **7.2 Exemplo: Basic HTML Data Extraction**
#
# **2º passo**: identificar o dado dentro do HTML
#
# <img src="media/imgs/webscrapping101.png">

# %% [markdown]
# ### **7.2 Exemplo: Basic HTML Data Extraction**
#
# **3º passo**: realizar a requisição via `requests`

# %%
import requests
url = "https://tryscrapeme.com/web-scraping-practice/beginner/abc"
resp = requests.get(url)
print(f"Status HTTP: {resp.status_code}")
print(resp.text)
# Out:
# Status HTTP: 200
#
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <meta name="robots" content="index, follow">
#
#     <meta name="keywords" content="request,html-parsing,xpath,css-selector,beginner">
#
#
#     <meta name="description" content="This is a beginner-friendly web scraping challenge.You can complete it using basic HTTP requests and HTML parsing.">
#
#     <link rel="canonical" href="https://tryscrapeme.com/web-scraping-practice/beginner/abc">
#     <link rel="stylesheet" href="/static/css/style.v5.min.css">
#     <script defer src="https://cdn.paddle.com/paddle/v2/paddle.js"></script>
#     <script defer src="https://tryscrapeme.com/static/js/htmx2.0.7.min.js"></script>
#     <script defer src="/static/js/site.v5.min.js"></script>
#     <title>Basic HTML Data Extraction | TryScrapeMe | Web Scraping Practice Website with Tutorials & Challenges
#     </title>
#
#     <script async src="https://www.googletagmanager.com/gtag/js?id=G-5DBZ7E3LXG"></script>
#     <script>
#         window.dataLayer = window.dataLayer || [];
#         function gtag() {dataLayer.push(arguments);}
#         gtag('js', new Date());
#         gtag('config', 'G-5DBZ7E3LXG');
#     </script>
# </head>
#
# <body class="flex flex-col justify-between min-h-screen">
#     <div class="spinner"></div>
#     <header class="border-b border-gray-200">
#       <div class="max-w-7xl mx-auto px-4 sm:px-6 lg:px-8 flex items-center justify-between">
#           <div class="flex gap-2 items-center">
#               <div><img class="w-10 h-10 pt-2" src="https://tryscrapeme.com/static/images/logo.png" alt="TryScrapeMe"></div>
#               <div class="text-xl font-bold"><a class="text-gray-800" href="https://tryscrapeme.com/"
#                       title="Practice Your Web Scraping Skills">TryScrapeMe</a></div>
#           </div>
#           <nav class="flex items-center gap-12">
#               <a class="text-slate-800 hover:text-indigo-600" href="https://tryscrapeme.com/challenges">Challenges</a>
#               <a class="text-slate-800 hover:text-indigo-600" href="https://tryscrapeme.com/pricing">Pricing</a>
#               <a class="text-slate-800 hover:text-indigo-600" target="_blank" href="https://tryscrapeme.com/docs">Docs</a>
#
#               <a class="text-slate-800 hover:text-indigo-600" href="https://tryscrapeme.com/login">Login</a>
#
#           </nav>
#       </div>
#     </header>
# <section  class="min-h-[90vh] flex flex-col items-center">
#     <div class="max-w-[65rem] w-[65rem] py-8">
# <div class="max-w-3xl mx-auto mb-12">
#
#     <div class="bg-white border border-gray-200 rounded-2xl overflow-hidden">
#
#         <div class="px-8 py-6 border-b border-gray-100">
#             <div class="flex justify-between items-start gap-4">
#                 <h1 class="text-2xl font-bold text-gray-900 tracking-tight">Basic HTML Data Extraction</h1>
#
#                 <button class="challenge-action flex-shrink-0 mt-2"
#                         popovertarget="challenge-help"
#                         aria-label="Help">
#                     <img src="https://tryscrapeme.com/static/images/help-circle.svg"
#                          alt="Help"
#                          class="w-5 h-5 opacity-80 hover:opacity-100 transition-opacity">
#                 </button>
#             </div>
#         </div>
#
#         <div class="p-8 flex flex-col gap-7">
#
#             <div class="inline-flex items-center gap-2">
#                 <span class="text-gray-900">Calculate the total value of the price column from the scraped data.</span>
#             </div>
#
#             <div class="text-sm leading-7 text-gray-600">
#                 This is a beginner-friendly web scraping challenge.You can complete it using basic HTTP requests and HTML parsing.
#             </div>
#
#             <div class="flex flex-wrap gap-x-8 gap-y-3 text-sm">
#                 <div class="flex items-center gap-2">
#                     <span class="text-gray-500">Difficulty:</span>
#                     <span class="px-4 py-1.5 bg-gray-100 text-gray-700 font-medium rounded-2xl capitalize">
#                         beginner
#                     </span>
#                 </div>
#
#                 <div class="flex items-center gap-2">
#                     <span class="text-gray-500">Tags:</span>
#                     <span class="text-gray-600">request · html-parsing · xpath · css-selector · beginner</span>
#                 </div>
#
#             </div>
#         </div>
#
#         <div class="px-8 py-6 bg-white border-t border-gray-100">
#             <div class="flex items-center justify-end">
#                 <div class="flex items-center gap-8">
#                     <a href="https://tryscrapeme.com/guide/abc" class="text-gray-600 hover:text-gray-900">
#                         Verify Solution
#                     </a>
#                     <a href="https://tryscrapeme.com/guide/abc" class="inline-flex items-center rounded-xl bg-slate-900 px-4 py-2 text-sm font-medium text-white hover:bg-slate-950">
#                         View Engineering Walkthrough
#                     </a>
#                 </div>
#             </div>
#         </div>
#     </div>
# </div>
#
# <div popover id="challenge-help"
#      class="max-w-md w-full p-9 rounded-2xl border border-gray-200 shadow-xl bg-white">
#     <h2 class="text-2xl font-semibold text-gray-900 mb-6">Web Scraping Practice</h2>
#     <p class="text-gray-600 mb-6">
#         This page is built specifically for practicing web scraping skills in a realistic environment.
#     </p>
#     <h3 class="font-medium text-gray-800 mb-3">This challenge may involve:</h3>
#     <ul class="space-y-2.5 text-gray-600 mb-8">
#         <li class="flex gap-2">
#             <span class="text-emerald-600 mt-0.5">→</span>
#             <span>Pagination and dynamic content</span>
#         </li>
#         <li class="flex gap-2">
#             <span class="text-emerald-600 mt-0.5">→</span>
#             <span>Authentication and session handling</span>
#         </li>
#         <li class="flex gap-2">
#             <span class="text-emerald-600 mt-0.5">→</span>
#             <span>Structured data extraction</span>
#         </li>
#         <li class="flex gap-2">
#             <span class="text-emerald-600 mt-0.5">→</span>
#             <span>Production-style scraping patterns</span>
#         </li>
#     </ul>
#     <div class="pt-6 border-t border-gray-100 flex items-center justify-center">
#         <a href="https://tryscrapeme.com/guide/abc">
#            View Engineering Walkthrough →
#         </a>
#     </div>
# </div>
# <table>
#            	<thead>
#                 <tr>
#                     <th>name</th>
#                     <th>author</th>
#                     <th>stars</th>
#                     <th data-field="price">price</th>
#                 </tr>
#            	</thead>
#            	<tbody>
#                 <tr>
#                     <td>Clean Code</td>
#                     <td>Robert C. Martin</td>
#                     <td>4.5</td>
#                     <td>26.56</td>
#                 </tr>
#                 <tr>
#                     <td>The Legend of Zelda</td>
#                     <td>Shigeru Miyamoto</td>
#                     <td>4.5</td>
#                     <td>27.56</td>
#                 </tr>
#                 <tr>
#                     <td>Don't Make Me Think, Revisited</td>
#                     <td>Steve Krug</td>
#                     <td>4</td>
#                     <td>23.03</td>
#                 </tr>
#                 <tr>
#                     <td>Godel, Escher, Bach</td>
#                     <td>Douglas R. Hofstadter</td>
#                     <td>4.5</td>
#                     <td>16.37</td>
#                 </tr>
#                 <tr>
#                     <td>Superintelligence</td>
#                     <td>Nick Bostrom</td>
#                     <td>4</td>
#                     <td>9.93</td>
#                 </tr>
#                 <tr>
#                     <td>Web Design with HTML, CSS, JavaScript and jQuery Set</td>
#                     <td>Jon Duckett</td>
#                     <td>4.5</td>
#                     <td>29.93</td>
#                 </tr>
#                 <tr>
#                     <td>Cracking the Coding Interview</td>
#                     <td>Gayle Laakmann McDowell</td>
#                     <td>4.5</td>
#                     <td>33.99</td>
#                 </tr>
#                 <tr>
#                     <td>The Internet is a Playground</td>
#                     <td>David Thorne</td>
#                     <td>4</td>
#                     <td>15.09</td>
#                 </tr>
#                 <tr>
#                     <td>DanTDM: Trayaurus and the Enchanted Crystal</td>
#                     <td>DanTDM</td>
#                     <td>4.5</td>
#                     <td>14.93</td>
#                 </tr>
#                 <tr>
#                     <td>Life 3.0</td>
#                     <td>Max Tegmark</td>
#                     <td>4</td>
#                     <td>10</td>
#                 </tr>
#             </tbody>
#         </table>
#     </div>
# </section>
# <footer class="flex flex-wrap items-center justify-center gap-6 text-sm py-4 border-t border-t-gray-200">
#         <span class="text-gray-600">© TryScrapeMe</span>
#         <a class="text-slate-600 hover:text-indigo-600" href="https://tryscrapeme.com/about">About</a>
#         <a class="text-gray-600 hover:text-indigo-800" href="https://tryscrapeme.com/privacy">Privacy</a>
#         <a class="text-gray-600 hover:text-indigo-800" href="https://tryscrapeme.com/terms">Terms</a>
#         <a class="text-gray-600 hover:text-indigo-800" href="https://tryscrapeme.com/faq">FAQ</a>
#         <a class="text-gray-600 hover:text-indigo-800" href="https://tryscrapeme.com/contactus">Contact Us</a>
#     </footer>
# </body>
#
# </html>

# %% [markdown]
# ### **7.2 Exemplo: Basic HTML Data Extraction**
#
# **4º passo**: filtrar os dados dentro do HTML

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(resp.text, "html.parser")
soma = 0
for tr in soup.select('table tbody tr'):
    td4 = tr.select_one('td:nth-of-type(4)')
    if td4:
        valor = float(td4.get_text())
        soma += valor
        print(valor, end=' ')
print(f"\nSoma: {soma}")
# Out:
# 26.56 27.56 23.03 16.37 9.93 29.93 33.99 15.09 14.93 10.0
# Soma: 207.39000000000004

# %% [markdown]
# ## 8. Realizar a prospecção de trabalhos acadêmicos
#
# ### **8.1 Plataformas acadêmicas**
#
# - [Google Acadêmico](https://scholar.google.com/schhp): O Google Scholar, ou Google Acadêmico, é uma ferramenta de busca gratuita do Google voltada para pesquisas acadêmicas, permitindo acessar artigos, teses, livros e outras publicações científicas;
# - [ResearchGate](https://www.researchgate.net/): Rede social acadêmica gratuita que conecta pesquisadores e cientistas de todo o mundo;
# - [ScienceDirect](https://www.sciencedirect.com/): Plataforma online da Elsevier que oferece acesso a artigos científicos e livros revisados por pares em diversas áreas do conhecimento;
# - [Wiley](https://onlinelibrary.wiley.com/): Wiley é uma companhia americana de publicações multinacional;
# - [Periódicos CAPES](https://www-periodicos-capes-gov-br.ez59.periodicos.capes.gov.br/index.php): Acesso irrestrito do conteúdo do portal pelos usuários e o compartilhamento das pesquisas brasileiras em nível internacional;
# - ...

# %% [markdown]
# ### **8.2 Algoritmo básico**
#
# 1. Defina o problema e os termos de pesquisa
# 2. Busca exploratória ampla por artigos de revisão
# 3. Filtre por métricas como fator de impacto, Qualis ou Cite Score
# 4. Organize a juntada de artigos
# 5. Altere um pouco os termos de pesquisa e a plataforma
# 6. Fa?a uma busca refinada sobre os novos termos de pesquisa
# 7. Repita
# 8. Verifique por artigos repetidos

# %% [markdown]
# ## Lista de exercícios suplementares (desafios)
#
# **Exercício S1.** Utilizando a API obsoleta do INMET e análise do HTML das páginas (dicas [aqui](https://tempo.inmet.gov.br/TabelaEstacoes/A001),[aqui](https://github.com/ocfgaldino/inmetpy), [aqui](https://apitempo.inmet.gov.br/estacoes/M), [aqui](https://gist.github.com/andradelis/e153f2d490395f75e2c060f2d4eb0002), [aqui](https://inmet-api-front.vercel.app/) e [aqui](https://apisat.inmet.gov.br/GOES/BR/IV/2026-5-27/14:40)),  obtenha os dados de precipitação acumulada das estações automáticas do estado do RJ para os últimos 30 dias. Qual estação registrou maior precipitação?
#
# **Exercício S2.** Implemente um web scraper ético que colete dados de uma tabela de um portal público de sua escolha (ex.: dados de licitações, notas fiscais ambientais, registros de queimadas). Inclua: tratamento de erros, respeito ao `robots.txt` e pausa entre requisições.
